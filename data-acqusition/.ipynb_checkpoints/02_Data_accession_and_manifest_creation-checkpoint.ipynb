# %%
import numpy as np
import pandas as pd
import glob

# %% [markdown]
# Primero cargamos la encuesta del American Gut Project extraida de Qiita (study=10317) el 11 de abril de 2022.

# %%
survey = pd.read_table('metadata_survey.tsv', low_memory=False)
survey
# Out:
#                        sample_name     acid_reflux acne_medication  \
# 0                  10317.000001000    Not provided           false
# 1                  10317.000001001    Not provided           false
# 2                  10317.000001002    Not provided           false
# 3                  10317.000001004    Not provided           false
# 4                  10317.000001008    Not provided           false
# ...                            ...             ...             ...
# 34787      10317.blank3.ragOffice1  Not applicable  Not applicable
# 34788      10317.blank4.ragOffice1  Not applicable  Not applicable
# 34789    10317.zymo.mock.barcode53  Not applicable  Not applicable
# 34790    10317.zymo.mock.barcode75  Not applicable  Not applicable
# 34791  10317.zymo.mock.barcode75r2  Not applicable  Not applicable
#
#       acne_medication_otc                                           add_adhd  \
# 0                   false  Diagnosed by a medical professional (doctor, p...
# 1                   false                                       Not provided
# 2                   false                                       Not provided
# 3                   false                                       Not provided
# 4                   false                                       Not provided
# ...                   ...                                                ...
# 34787      Not applicable                                     Not applicable
# 34788      Not applicable                                     Not applicable
# 34789      Not applicable                                     Not applicable
# 34790      Not applicable                                     Not applicable
# 34791      Not applicable                                     Not applicable
#
#               age_cat       age_years alcohol_consumption  \
# 0                 60s              64                true
# 1                 50s            53.0                true
# 2                 50s            53.0                true
# 3                 40s            44.0                true
# 4                 60s            66.0               false
# ...               ...             ...                 ...
# 34787  Not applicable  Not applicable      Not applicable
# 34788  Not applicable  Not applicable      Not applicable
# 34789  Not applicable  Not applicable      Not applicable
# 34790  Not applicable  Not applicable      Not applicable
# 34791  Not applicable  Not applicable      Not applicable
#
#                 alcohol_frequency alcohol_types_beercider  ...  \
# 0                           Daily                    true  ...
# 1      Rarely (a few times/month)                   false  ...
# 2      Regularly (3-5 times/week)                   false  ...
# 3      Rarely (a few times/month)                   false  ...
# 4                           Never                   false  ...
# ...                           ...                     ...  ...
# 34787              Not applicable          Not applicable  ...
# 34788              Not applicable          Not applicable  ...
# 34789              Not applicable          Not applicable  ...
# 34790              Not applicable          Not applicable  ...
# 34791              Not applicable          Not applicable  ...
#
#       vioscreen_wgrain vioscreen_whole_grain_servings vioscreen_xylitol  \
# 0         Not provided                   Not provided      Not provided
# 1         Not provided                   Not provided      Not provided
# 2         Not provided                   Not provided      Not provided
# 3         Not provided                   Not provided      Not provided
# 4         Not provided                   Not provided      Not provided
# ...                ...                            ...               ...
# 34787   Not applicable                 Not applicable    Not applicable
# 34788   Not applicable                 Not applicable    Not applicable
# 34789              NaN                            NaN               NaN
# 34790              NaN                            NaN               NaN
# 34791              NaN                            NaN               NaN
#
#        vioscreen_zinc vitamin_b_supplement_frequency  \
# 0        Not provided                          Never
# 1        Not provided                   Not provided
# 2        Not provided                   Not provided
# 3        Not provided                   Not provided
# 4        Not provided                   Not provided
# ...               ...                            ...
# 34787  Not applicable                 Not applicable
# 34788  Not applicable                 Not applicable
# 34789             NaN                 Not applicable
# 34790             NaN                 Not applicable
# 34791             NaN                 Not applicable
#
#       vitamin_d_supplement_frequency    vivid_dreams  \
# 0         Regularly (3-5 times/week)    Not provided
# 1                       Not provided    Not provided
# 2                       Not provided    Not provided
# 3                       Not provided    Not provided
# 4                       Not provided    Not provided
# ...                              ...             ...
# 34787                 Not applicable  Not applicable
# 34788                 Not applicable  Not applicable
# 34789                 Not applicable  Not applicable
# 34790                 Not applicable  Not applicable
# 34791                 Not applicable  Not applicable
#
#                        weight_change      whole_eggs  \
# 0                    Remained stable           Never
# 1                    Remained stable    Not provided
# 2                       Not provided    Not provided
# 3                    Remained stable    Not provided
# 4      Increased more than 10 pounds    Not provided
# ...                              ...             ...
# 34787                 Not applicable  Not applicable
# 34788                 Not applicable  Not applicable
# 34789                 Not applicable  Not applicable
# 34790                 Not applicable  Not applicable
# 34791                 Not applicable  Not applicable
#
#                whole_grain_frequency
# 0      Occasionally (1-2 times/week)
# 1                       Not provided
# 2                       Not provided
# 3                       Not provided
# 4                       Not provided
# ...                              ...
# 34787                 Not applicable
# 34788                 Not applicable
# 34789                 Not applicable
# 34790                 Not applicable
# 34791                 Not applicable
#
# [34792 rows x 723 columns]

# %% [markdown]
# Ahora cargamos la tabla con la información de acceso de todas las lecturas disponibles en el ENA (esta tabla se extrajo también del ENA).

# %%
reference = pd.read_table('filereport_read_run_PRJEB11419.tsv')
reference
# Out:
#       study_accession sample_accession experiment_accession run_accession  \
# 0          PRJEB11419     SAMEA3607589           ERX1152774    ERR1072624
# 1          PRJEB11419     SAMEA3607590           ERX1152775    ERR1072625
# 2          PRJEB11419     SAMEA3607591           ERX1152776    ERR1072626
# 3          PRJEB11419     SAMEA3607592           ERX1152777    ERR1072627
# 4          PRJEB11419     SAMEA3607593           ERX1152778    ERR1072628
# ...               ...              ...                  ...           ...
# 38342      PRJEB11419     SAMEA8947742           ERX8044363    ERR8477542
# 38343      PRJEB11419    SAMEA12869767           ERX8044364    ERR8477543
# 38344      PRJEB11419     SAMEA8947832           ERX8044365    ERR8477544
# 38345      PRJEB11419     SAMEA8947895           ERX8044366    ERR8477545
# 38346      PRJEB11419     SAMEA8947994           ERX8044367    ERR8477546
#
#        tax_id       scientific_name  \
# 0      408170  human gut metagenome
# 1      408170  human gut metagenome
# 2      408170  human gut metagenome
# 3      408170  human gut metagenome
# 4      408170  human gut metagenome
# ...       ...                   ...
# 38342  408170  human gut metagenome
# 38343  408170  human gut metagenome
# 38344  408170  human gut metagenome
# 38345  408170  human gut metagenome
# 38346  408170  human gut metagenome
#
#                                                fastq_ftp  \
# 0      ftp.sra.ebi.ac.uk/vol1/fastq/ERR107/004/ERR107...
# 1      ftp.sra.ebi.ac.uk/vol1/fastq/ERR107/005/ERR107...
# 2      ftp.sra.ebi.ac.uk/vol1/fastq/ERR107/006/ERR107...
# 3      ftp.sra.ebi.ac.uk/vol1/fastq/ERR107/007/ERR107...
# 4      ftp.sra.ebi.ac.uk/vol1/fastq/ERR107/008/ERR107...
# ...                                                  ...
# 38342  ftp.sra.ebi.ac.uk/vol1/fastq/ERR847/002/ERR847...
# 38343  ftp.sra.ebi.ac.uk/vol1/fastq/ERR847/003/ERR847...
# 38344  ftp.sra.ebi.ac.uk/vol1/fastq/ERR847/004/ERR847...
# 38345  ftp.sra.ebi.ac.uk/vol1/fastq/ERR847/005/ERR847...
# 38346  ftp.sra.ebi.ac.uk/vol1/fastq/ERR847/006/ERR847...
#
#                                            submitted_ftp  \
# 0      ftp.sra.ebi.ac.uk/vol1/run/ERR107/ERR1072624/1...
# 1      ftp.sra.ebi.ac.uk/vol1/run/ERR107/ERR1072625/1...
# 2      ftp.sra.ebi.ac.uk/vol1/run/ERR107/ERR1072626/1...
# 3      ftp.sra.ebi.ac.uk/vol1/run/ERR107/ERR1072627/1...
# 4      ftp.sra.ebi.ac.uk/vol1/run/ERR107/ERR1072628/1...
# ...                                                  ...
# 38342  ftp.sra.ebi.ac.uk/vol1/run/ERR847/ERR8477542/1...
# 38343  ftp.sra.ebi.ac.uk/vol1/run/ERR847/ERR8477543/1...
# 38344  ftp.sra.ebi.ac.uk/vol1/run/ERR847/ERR8477544/1...
# 38345  ftp.sra.ebi.ac.uk/vol1/run/ERR847/ERR8477545/1...
# 38346  ftp.sra.ebi.ac.uk/vol1/run/ERR847/ERR8477546/1...
#
#                                                 sra_ftp
# 0      ftp.sra.ebi.ac.uk/vol1/err/ERR107/004/ERR1072624
# 1      ftp.sra.ebi.ac.uk/vol1/err/ERR107/005/ERR1072625
# 2      ftp.sra.ebi.ac.uk/vol1/err/ERR107/006/ERR1072626
# 3      ftp.sra.ebi.ac.uk/vol1/err/ERR107/007/ERR1072627
# 4      ftp.sra.ebi.ac.uk/vol1/err/ERR107/008/ERR1072628
# ...                                                 ...
# 38342                                               NaN
# 38343                                               NaN
# 38344                                               NaN
# 38345                                               NaN
# 38346                                               NaN
#
# [38347 rows x 9 columns]

# %% [markdown]
# Ahora, cargamos las tablas que contienen la información del numbre de la muestra asignado en el AGT para cada muestra con su respectiva información de acceso en el ENA, y las vamos a concatenar todas en una sola tabla para facilitar su manipulación. Todas estas tablas fueron obtneidas de Qiita.

# %%
accession_files = glob.glob('ebi-experiment-accessions/ebi_experiment_accessions_study_10317_prep_*.tsv')
accessions = [pd.read_table(i, dtype=str) for i in accession_files]
accessions
accession = pd.concat(accessions, ignore_index=True)
accession = accession[accession['experiment_accession'] != 'None']
accession
# Out:
#            sample_name experiment_accession
# 5      10317.000001389           ERX1154303
# 6      10317.000001265           ERX1154299
# 7      10317.000001759           ERX1154324
# 8      10317.000002567           ERX1154366
# 9      10317.000002202           ERX1154347
# ...                ...                  ...
# 33843  10317.000015453           ERX1157670
# 33844  10317.000015451           ERX1157668
# 33845  10317.000015900           ERX1157683
# 33846  10317.000015901           ERX1157684
# 33847  10317.000015455           ERX1157671
#
# [33251 rows x 2 columns]

# %% [markdown]
# En este paso, unimos todas las tablas mapenado la información relevante de cada tabla y agregamos las columnas necesarias para crear el "manifest file" para poder importar los datos a Qiime2.

# %%
metadata = survey.merge(accession, on = 'sample_name')
metadata = metadata.merge(reference, on = 'experiment_accession')
absolute_path = '/hpcfs/home/cursos/biocom4102/Grupo_5/Proyecto/data-acquisition/raw-data'
metadata['sample-id'] = metadata['fastq_ftp'] \
                        .str.replace('ftp.sra.ebi.ac.uk/vol1/fastq/ERR\d\d\d/\d\d\d/ERR\d\d\d\d\d\d\d/', '', regex=True) \
                        .str.replace('.fastq.gz', '', regex=False)
absolute_filepath = ['{0}/{1}.fastq.gz'.format(absolute_path, i) for i in metadata['sample-id']]
metadata['absolute-filepath'] = absolute_filepath
metadata.set_index('sample-id', inplace = True)
metadata
# Out:
#                         sample_name     acid_reflux acne_medication  \
# sample-id
# ERR2032460          10317.000001000    Not provided           false
# ERR1073439          10317.000001001    Not provided           false
# ERR1072624          10317.000001002    Not provided           false
# ERR1072625          10317.000001004    Not provided           false
# ERR1072626          10317.000001008    Not provided           false
# ...                             ...             ...             ...
# ERR5332644        10317.blank275.2F  Not applicable  Not applicable
# ERR5332645        10317.blank275.2G  Not applicable  Not applicable
# ERR5332646        10317.blank275.2H  Not applicable  Not applicable
# ERR2092759  10317.blank3.ragOffice1  Not applicable  Not applicable
# ERR2092760  10317.blank4.ragOffice1  Not applicable  Not applicable
#
#            acne_medication_otc  \
# sample-id
# ERR2032460               false
# ERR1073439               false
# ERR1072624               false
# ERR1072625               false
# ERR1072626               false
# ...                        ...
# ERR5332644      Not applicable
# ERR5332645      Not applicable
# ERR5332646      Not applicable
# ERR2092759      Not applicable
# ERR2092760      Not applicable
#
#                                                      add_adhd         age_cat  \
# sample-id
# ERR2032460  Diagnosed by a medical professional (doctor, p...             60s
# ERR1073439                                       Not provided             50s
# ERR1072624                                       Not provided             50s
# ERR1072625                                       Not provided             40s
# ERR1072626                                       Not provided             60s
# ...                                                       ...             ...
# ERR5332644                                     Not applicable  Not applicable
# ERR5332645                                     Not applicable  Not applicable
# ERR5332646                                     Not applicable  Not applicable
# ERR2092759                                     Not applicable  Not applicable
# ERR2092760                                     Not applicable  Not applicable
#
#                  age_years alcohol_consumption           alcohol_frequency  \
# sample-id
# ERR2032460              64                true                       Daily
# ERR1073439            53.0                true  Rarely (a few times/month)
# ERR1072624            53.0                true  Regularly (3-5 times/week)
# ERR1072625            44.0                true  Rarely (a few times/month)
# ERR1072626            66.0               false                       Never
# ...                    ...                 ...                         ...
# ERR5332644  Not applicable      Not applicable              Not applicable
# ERR5332645  Not applicable      Not applicable              Not applicable
# ERR5332646  Not applicable      Not applicable              Not applicable
# ERR2092759  Not applicable      Not applicable              Not applicable
# ERR2092760  Not applicable      Not applicable              Not applicable
#
#            alcohol_types_beercider  ... experiment_accession study_accession  \
# sample-id                           ...
# ERR2032460                    true  ...           ERX2091517      PRJEB11419
# ERR1073439                   false  ...           ERX1153583      PRJEB11419
# ERR1072624                   false  ...           ERX1152774      PRJEB11419
# ERR1072625                   false  ...           ERX1152775      PRJEB11419
# ERR1072626                   false  ...           ERX1152776      PRJEB11419
# ...                            ...  ...                  ...             ...
# ERR5332644          Not applicable  ...           ERX5121028      PRJEB11419
# ERR5332645          Not applicable  ...           ERX5121029      PRJEB11419
# ERR5332646          Not applicable  ...           ERX5121030      PRJEB11419
# ERR2092759          Not applicable  ...           ERX2149982      PRJEB11419
# ERR2092760          Not applicable  ...           ERX2149983      PRJEB11419
#
#            sample_accession run_accession  tax_id     scientific_name_y  \
# sample-id
# ERR2032460   SAMEA104162584    ERR2032460  408170  human gut metagenome
# ERR1073439     SAMEA3608371    ERR1073439  408170  human gut metagenome
# ERR1072624     SAMEA3607589    ERR1072624  408170  human gut metagenome
# ERR1072625     SAMEA3607590    ERR1072625  408170  human gut metagenome
# ERR1072626     SAMEA3607591    ERR1072626  408170  human gut metagenome
# ...                     ...           ...     ...                   ...
# ERR5332644     SAMEA8115082    ERR5332644  256318            metagenome
# ERR5332645     SAMEA8115083    ERR5332645  256318            metagenome
# ERR5332646     SAMEA8115084    ERR5332646  256318            metagenome
# ERR2092759   SAMEA104207122    ERR2092759  256318            metagenome
# ERR2092760   SAMEA104207123    ERR2092760  256318            metagenome
#
#                                                     fastq_ftp  \
# sample-id
# ERR2032460  ftp.sra.ebi.ac.uk/vol1/fastq/ERR203/000/ERR203...
# ERR1073439  ftp.sra.ebi.ac.uk/vol1/fastq/ERR107/009/ERR107...
# ERR1072624  ftp.sra.ebi.ac.uk/vol1/fastq/ERR107/004/ERR107...
# ERR1072625  ftp.sra.ebi.ac.uk/vol1/fastq/ERR107/005/ERR107...
# ERR1072626  ftp.sra.ebi.ac.uk/vol1/fastq/ERR107/006/ERR107...
# ...                                                       ...
# ERR5332644  ftp.sra.ebi.ac.uk/vol1/fastq/ERR533/004/ERR533...
# ERR5332645  ftp.sra.ebi.ac.uk/vol1/fastq/ERR533/005/ERR533...
# ERR5332646  ftp.sra.ebi.ac.uk/vol1/fastq/ERR533/006/ERR533...
# ERR2092759  ftp.sra.ebi.ac.uk/vol1/fastq/ERR209/009/ERR209...
# ERR2092760  ftp.sra.ebi.ac.uk/vol1/fastq/ERR209/000/ERR209...
#
#                                                 submitted_ftp  \
# sample-id
# ERR2032460  ftp.sra.ebi.ac.uk/vol1/run/ERR203/ERR2032460/1...
# ERR1073439  ftp.sra.ebi.ac.uk/vol1/run/ERR107/ERR1073439/1...
# ERR1072624  ftp.sra.ebi.ac.uk/vol1/run/ERR107/ERR1072624/1...
# ERR1072625  ftp.sra.ebi.ac.uk/vol1/run/ERR107/ERR1072625/1...
# ERR1072626  ftp.sra.ebi.ac.uk/vol1/run/ERR107/ERR1072626/1...
# ...                                                       ...
# ERR5332644  ftp.sra.ebi.ac.uk/vol1/run/ERR533/ERR5332644/1...
# ERR5332645  ftp.sra.ebi.ac.uk/vol1/run/ERR533/ERR5332645/1...
# ERR5332646  ftp.sra.ebi.ac.uk/vol1/run/ERR533/ERR5332646/1...
# ERR2092759  ftp.sra.ebi.ac.uk/vol1/run/ERR209/ERR2092759/1...
# ERR2092760  ftp.sra.ebi.ac.uk/vol1/run/ERR209/ERR2092760/1...
#
#                                                      sra_ftp  \
# sample-id
# ERR2032460  ftp.sra.ebi.ac.uk/vol1/err/ERR203/000/ERR2032460
# ERR1073439  ftp.sra.ebi.ac.uk/vol1/err/ERR107/009/ERR1073439
# ERR1072624  ftp.sra.ebi.ac.uk/vol1/err/ERR107/004/ERR1072624
# ERR1072625  ftp.sra.ebi.ac.uk/vol1/err/ERR107/005/ERR1072625
# ERR1072626  ftp.sra.ebi.ac.uk/vol1/err/ERR107/006/ERR1072626
# ...                                                      ...
# ERR5332644                                               NaN
# ERR5332645                                               NaN
# ERR5332646                                               NaN
# ERR2092759  ftp.sra.ebi.ac.uk/vol1/err/ERR209/009/ERR2092759
# ERR2092760  ftp.sra.ebi.ac.uk/vol1/err/ERR209/000/ERR2092760
#
#                                             absolute-filepath
# sample-id
# ERR2032460  /hpcfs/home/cursos/biocom4102/Grupo_5/Proyecto...
# ERR1073439  /hpcfs/home/cursos/biocom4102/Grupo_5/Proyecto...
# ERR1072624  /hpcfs/home/cursos/biocom4102/Grupo_5/Proyecto...
# ERR1072625  /hpcfs/home/cursos/biocom4102/Grupo_5/Proyecto...
# ERR1072626  /hpcfs/home/cursos/biocom4102/Grupo_5/Proyecto...
# ...                                                       ...
# ERR5332644  /hpcfs/home/cursos/biocom4102/Grupo_5/Proyecto...
# ERR5332645  /hpcfs/home/cursos/biocom4102/Grupo_5/Proyecto...
# ERR5332646  /hpcfs/home/cursos/biocom4102/Grupo_5/Proyecto...
# ERR2092759  /hpcfs/home/cursos/biocom4102/Grupo_5/Proyecto...
# ERR2092760  /hpcfs/home/cursos/biocom4102/Grupo_5/Proyecto...
#
# [33435 rows x 733 columns]

# %% [markdown]
# Ahora filtramos la tabla para obtener únicamente las observaciones que son de nuestro interés. En este caso, nos importa que de las muestras se haya hecho efectivamente la extracción y secuenciación del ADN, que el individuo sea sano (definido como todo individuo entre el rango de edad de los 18 y los 69 años, con un indice de masa corporal entre 18.5 y 30, que no haya reportado que consumió antibióticos en el el transcurso de un año antes de haberse tomado la muestra, y que no haya reportado tener diabetes ni síndrome del colon irritable), que la muestra sea del intestino humano y que el individuo sea residente de los Estados Unidos.

# %%
metadata_filtered = metadata[(metadata['dna_extracted'] == True) & \
                             (metadata['subset_healthy'] == 'true') & \
                             (metadata['env_package'] == 'human-gut') & \
                             (metadata['country_residence'] == 'United States')].copy()
metadata_filtered
# Out:
#                 sample_name                   acid_reflux acne_medication  \
# sample-id
# ERR2032461  10317.000001166  I do not have this condition           false
# ERR1315794  10317.000001527  I do not have this condition           false
# ERR1389625  10317.000002033  I do not have this condition            true
# ERR1389626  10317.000002034  I do not have this condition           false
# ERR2313941  10317.000002224  I do not have this condition           false
# ...                     ...                           ...             ...
# ERR2314356  10317.000073252  I do not have this condition           false
# ERR2314357  10317.000073253  I do not have this condition           false
# ERR2314358  10317.000073260  I do not have this condition           false
# ERR2314359  10317.000073262                Self-diagnosed           false
# ERR2314373  10317.000073344  I do not have this condition           false
#
#            acne_medication_otc                      add_adhd age_cat  \
# sample-id
# ERR2032461               false  I do not have this condition     40s
# ERR1315794               false  I do not have this condition     60s
# ERR1389625               false  I do not have this condition     30s
# ERR1389626                true  I do not have this condition     40s
# ERR2313941               false                Self-diagnosed     30s
# ...                        ...                           ...     ...
# ERR2314356               false  I do not have this condition     40s
# ERR2314357               false  I do not have this condition     40s
# ERR2314358               false  I do not have this condition     60s
# ERR2314359               false  I do not have this condition     50s
# ERR2314373               false  I do not have this condition     50s
#
#            age_years alcohol_consumption              alcohol_frequency  \
# sample-id
# ERR2032461        47                true     Regularly (3-5 times/week)
# ERR1315794      62.0                true     Regularly (3-5 times/week)
# ERR1389625      37.0                true  Occasionally (1-2 times/week)
# ERR1389626      40.0                true     Regularly (3-5 times/week)
# ERR2313941        36               false                          Never
# ...              ...                 ...                            ...
# ERR2314356        49                true     Rarely (a few times/month)
# ERR2314357        44               false                          Never
# ERR2314358        64                true     Regularly (3-5 times/week)
# ERR2314359        54                true                          Daily
# ERR2314373        58                true                          Daily
#
#            alcohol_types_beercider  ... experiment_accession study_accession  \
# sample-id                           ...
# ERR2032461                   false  ...           ERX2091518      PRJEB11419
# ERR1315794                   false  ...           ERX1387476      PRJEB11419
# ERR1389625                    true  ...           ERX1460883      PRJEB11419
# ERR1389626                    true  ...           ERX1460884      PRJEB11419
# ERR2313941                   false  ...           ERX2365233      PRJEB11419
# ...                            ...  ...                  ...             ...
# ERR2314356                   false  ...           ERX2365648      PRJEB11419
# ERR2314357                   false  ...           ERX2365649      PRJEB11419
# ERR2314358                   false  ...           ERX2365650      PRJEB11419
# ERR2314359                    true  ...           ERX2365651      PRJEB11419
# ERR2314373                    true  ...           ERX2365665      PRJEB11419
#
#            sample_accession run_accession  tax_id     scientific_name_y  \
# sample-id
# ERR2032461   SAMEA104162585    ERR2032461  408170  human gut metagenome
# ERR1315794     SAMEA3900918    ERR1315794  408170  human gut metagenome
# ERR1389625     SAMEA3947460    ERR1389625  408170  human gut metagenome
# ERR1389626     SAMEA3947461    ERR1389626  408170  human gut metagenome
# ERR2313941   SAMEA104602250    ERR2313941  408170  human gut metagenome
# ...                     ...           ...     ...                   ...
# ERR2314356   SAMEA104602611    ERR2314356  408170  human gut metagenome
# ERR2314357   SAMEA104602612    ERR2314357  408170  human gut metagenome
# ERR2314358   SAMEA104602613    ERR2314358  408170  human gut metagenome
# ERR2314359   SAMEA104602614    ERR2314359  408170  human gut metagenome
# ERR2314373   SAMEA104602628    ERR2314373  408170  human gut metagenome
#
#                                                     fastq_ftp  \
# sample-id
# ERR2032461  ftp.sra.ebi.ac.uk/vol1/fastq/ERR203/001/ERR203...
# ERR1315794  ftp.sra.ebi.ac.uk/vol1/fastq/ERR131/004/ERR131...
# ERR1389625  ftp.sra.ebi.ac.uk/vol1/fastq/ERR138/005/ERR138...
# ERR1389626  ftp.sra.ebi.ac.uk/vol1/fastq/ERR138/006/ERR138...
# ERR2313941  ftp.sra.ebi.ac.uk/vol1/fastq/ERR231/001/ERR231...
# ...                                                       ...
# ERR2314356  ftp.sra.ebi.ac.uk/vol1/fastq/ERR231/006/ERR231...
# ERR2314357  ftp.sra.ebi.ac.uk/vol1/fastq/ERR231/007/ERR231...
# ERR2314358  ftp.sra.ebi.ac.uk/vol1/fastq/ERR231/008/ERR231...
# ERR2314359  ftp.sra.ebi.ac.uk/vol1/fastq/ERR231/009/ERR231...
# ERR2314373  ftp.sra.ebi.ac.uk/vol1/fastq/ERR231/003/ERR231...
#
#                                                 submitted_ftp  \
# sample-id
# ERR2032461  ftp.sra.ebi.ac.uk/vol1/run/ERR203/ERR2032461/1...
# ERR1315794  ftp.sra.ebi.ac.uk/vol1/run/ERR131/ERR1315794/1...
# ERR1389625  ftp.sra.ebi.ac.uk/vol1/run/ERR138/ERR1389625/1...
# ERR1389626  ftp.sra.ebi.ac.uk/vol1/run/ERR138/ERR1389626/1...
# ERR2313941  ftp.sra.ebi.ac.uk/vol1/run/ERR231/ERR2313941/1...
# ...                                                       ...
# ERR2314356  ftp.sra.ebi.ac.uk/vol1/run/ERR231/ERR2314356/1...
# ERR2314357  ftp.sra.ebi.ac.uk/vol1/run/ERR231/ERR2314357/1...
# ERR2314358  ftp.sra.ebi.ac.uk/vol1/run/ERR231/ERR2314358/1...
# ERR2314359  ftp.sra.ebi.ac.uk/vol1/run/ERR231/ERR2314359/1...
# ERR2314373  ftp.sra.ebi.ac.uk/vol1/run/ERR231/ERR2314373/1...
#
#                                                      sra_ftp  \
# sample-id
# ERR2032461  ftp.sra.ebi.ac.uk/vol1/err/ERR203/001/ERR2032461
# ERR1315794  ftp.sra.ebi.ac.uk/vol1/err/ERR131/004/ERR1315794
# ERR1389625  ftp.sra.ebi.ac.uk/vol1/err/ERR138/005/ERR1389625
# ERR1389626  ftp.sra.ebi.ac.uk/vol1/err/ERR138/006/ERR1389626
# ERR2313941  ftp.sra.ebi.ac.uk/vol1/err/ERR231/001/ERR2313941
# ...                                                      ...
# ERR2314356  ftp.sra.ebi.ac.uk/vol1/err/ERR231/006/ERR2314356
# ERR2314357  ftp.sra.ebi.ac.uk/vol1/err/ERR231/007/ERR2314357
# ERR2314358  ftp.sra.ebi.ac.uk/vol1/err/ERR231/008/ERR2314358
# ERR2314359  ftp.sra.ebi.ac.uk/vol1/err/ERR231/009/ERR2314359
# ERR2314373  ftp.sra.ebi.ac.uk/vol1/err/ERR231/003/ERR2314373
#
#                                             absolute-filepath
# sample-id
# ERR2032461  /hpcfs/home/cursos/biocom4102/Grupo_5/Proyecto...
# ERR1315794  /hpcfs/home/cursos/biocom4102/Grupo_5/Proyecto...
# ERR1389625  /hpcfs/home/cursos/biocom4102/Grupo_5/Proyecto...
# ERR1389626  /hpcfs/home/cursos/biocom4102/Grupo_5/Proyecto...
# ERR2313941  /hpcfs/home/cursos/biocom4102/Grupo_5/Proyecto...
# ...                                                       ...
# ERR2314356  /hpcfs/home/cursos/biocom4102/Grupo_5/Proyecto...
# ERR2314357  /hpcfs/home/cursos/biocom4102/Grupo_5/Proyecto...
# ERR2314358  /hpcfs/home/cursos/biocom4102/Grupo_5/Proyecto...
# ERR2314359  /hpcfs/home/cursos/biocom4102/Grupo_5/Proyecto...
# ERR2314373  /hpcfs/home/cursos/biocom4102/Grupo_5/Proyecto...
#
# [1404 rows x 733 columns]

# %% [markdown]
# Acá definimos todas las columnas que nos interesan y el orden en que queremos que se dispongan.

# %%
columns_interest = ['absolute-filepath', 
                    'artificial_sweeteners',
                    'diet_type', 
                    'drinking_water_source', 
                    'env_package', 
                    'exercise_frequency', 
                    'fermented_plant_frequency', 
                    'frozen_dessert_frequency', 
                    'fruit_frequency', 
                    'gluten', 
                    'high_fat_red_meat_frequency',
                    'homecooked_meals_frequency',
                    'meat_eggs_frequency',
                    'milk_cheese_frequency',
                    'milk_substitute_frequency',
                    'multivitamin', 
                    'olive_oil',
                    'one_liter_of_water_a_day_frequency',
                    'other_supplement_frequency',
                    'prepared_meals_frequency', 
                    'probiotic_frequency',
                    'ready_to_eat_meals_frequency', 
                    'red_meat_frequency',  
                    'seafood_frequency', 
                    'specialized_diet_exclude_dairy', 
                    'specialized_diet_exclude_nightshades', 
                    'specialized_diet_exclude_refined_sugars', 
                    'specialized_diet_fodmap', 
                    'specialized_diet_halaal', 
                    'specialized_diet_i_do_not_eat_a_specialized_diet', 
                    'specialized_diet_kosher', 
                    'specialized_diet_modified_paleo_diet', 
                    'specialized_diet_other_restrictions_not_described_here', 
                    'specialized_diet_paleo_diet_or_primal_diet', 
                    'specialized_diet_raw_food_diet', 
                    'specialized_diet_unspecified', 
                    'specialized_diet_weston_price_or_other_low_grain_low_processed_food_diet', 
                    'sugar_sweetened_drink_frequency', 
                    'sugary_sweets_frequency', 
                    'vegetable_frequency', 
                    'vitamin_b_supplement_frequency', 
                    'vitamin_d_supplement_frequency', 
                    'whole_eggs', 
                    'whole_grain_frequency', 
                    'fastq_ftp']

# %% [markdown]
# Finalmente, creamos el manifest file y lo guardamos en formato tsv.

# %%
metadata_interest_filtered = metadata_filtered.loc[:, columns_interest]
metadata_interest_filtered.to_csv('manifest_file.tsv', sep = '\t')
metadata_interest_filtered
# Out:
#                                             absolute-filepath  \
# sample-id
# ERR2032461  /hpcfs/home/cursos/biocom4102/Grupo_5/Proyecto...
# ERR1315794  /hpcfs/home/cursos/biocom4102/Grupo_5/Proyecto...
# ERR1389625  /hpcfs/home/cursos/biocom4102/Grupo_5/Proyecto...
# ERR1389626  /hpcfs/home/cursos/biocom4102/Grupo_5/Proyecto...
# ERR2313941  /hpcfs/home/cursos/biocom4102/Grupo_5/Proyecto...
# ...                                                       ...
# ERR2314356  /hpcfs/home/cursos/biocom4102/Grupo_5/Proyecto...
# ERR2314357  /hpcfs/home/cursos/biocom4102/Grupo_5/Proyecto...
# ERR2314358  /hpcfs/home/cursos/biocom4102/Grupo_5/Proyecto...
# ERR2314359  /hpcfs/home/cursos/biocom4102/Grupo_5/Proyecto...
# ERR2314373  /hpcfs/home/cursos/biocom4102/Grupo_5/Proyecto...
#
#                  artificial_sweeteners                         diet_type  \
# sample-id
# ERR2032461  Rarely (a few times/month)                          Omnivore
# ERR1315794                       Never                          Omnivore
# ERR1389625  Rarely (a few times/month)                          Omnivore
# ERR1389626  Rarely (a few times/month)                          Omnivore
# ERR2313941                       Never                          Omnivore
# ...                                ...                               ...
# ERR2314356                       Never                          Omnivore
# ERR2314357                       Never  Omnivore but do not eat red meat
# ERR2314358                       Never        Vegetarian but eat seafood
# ERR2314359  Rarely (a few times/month)                          Omnivore
# ERR2314373                       Never                          Omnivore
#
#            drinking_water_source env_package             exercise_frequency  \
# sample-id
# ERR2032461                  City   human-gut                          Never
# ERR1315794                  City   human-gut     Regularly (3-5 times/week)
# ERR1389625                  City   human-gut                          Daily
# ERR1389626              Filtered   human-gut     Regularly (3-5 times/week)
# ERR2313941              Filtered   human-gut     Regularly (3-5 times/week)
# ...                          ...         ...                            ...
# ERR2314356                  City   human-gut     Regularly (3-5 times/week)
# ERR2314357                  City   human-gut  Occasionally (1-2 times/week)
# ERR2314358               Bottled   human-gut                          Daily
# ERR2314359                  City   human-gut                          Never
# ERR2314373              Filtered   human-gut                          Daily
#
#                fermented_plant_frequency       frozen_dessert_frequency  \
# sample-id
# ERR2032461                         Never                          Never
# ERR1315794    Regularly (3-5 times/week)     Regularly (3-5 times/week)
# ERR1389625  Rarely (less than once/week)   Rarely (less than once/week)
# ERR1389626                         Never                          Never
# ERR2313941  Rarely (less than once/week)   Rarely (less than once/week)
# ...                                  ...                            ...
# ERR2314356  Rarely (less than once/week)  Occasionally (1-2 times/week)
# ERR2314357                         Never                          Never
# ERR2314358                         Never  Occasionally (1-2 times/week)
# ERR2314359                         Never                          Never
# ERR2314373  Rarely (less than once/week)   Rarely (less than once/week)
#
#                           fruit_frequency  \
# sample-id
# ERR2032461  Occasionally (1-2 times/week)
# ERR1315794                          Never
# ERR1389625     Regularly (3-5 times/week)
# ERR1389626  Occasionally (1-2 times/week)
# ERR2313941     Regularly (3-5 times/week)
# ...                                   ...
# ERR2314356     Regularly (3-5 times/week)
# ERR2314357  Occasionally (1-2 times/week)
# ERR2314358                          Daily
# ERR2314359     Regularly (3-5 times/week)
# ERR2314373                          Daily
#
#                                                       gluten  ...  \
# sample-id                                                     ...
# ERR2032461                                                No  ...
# ERR1315794  I do not eat gluten because it makes me feel bad  ...
# ERR1389625                                                No  ...
# ERR1389626                                                No  ...
# ERR2313941                                                No  ...
# ...                                                      ...  ...
# ERR2314356  I do not eat gluten because it makes me feel bad  ...
# ERR2314357                                                No  ...
# ERR2314358  I do not eat gluten because it makes me feel bad  ...
# ERR2314359                                                No  ...
# ERR2314373                                                No  ...
#
#            specialized_diet_unspecified  \
# sample-id
# ERR2032461                        false
# ERR1315794                 Not provided
# ERR1389625                 Not provided
# ERR1389626                 Not provided
# ERR2313941                         true
# ...                                 ...
# ERR2314356                        false
# ERR2314357                        false
# ERR2314358                        false
# ERR2314359                        false
# ERR2314373                        false
#
#            specialized_diet_weston_price_or_other_low_grain_low_processed_food_diet  \
# sample-id
# ERR2032461                                                NaN
# ERR1315794                                                NaN
# ERR1389625                                                NaN
# ERR1389626                                                NaN
# ERR2313941                                                NaN
# ...                                                       ...
# ERR2314356                                                NaN
# ERR2314357                                                NaN
# ERR2314358                                                NaN
# ERR2314359                                                NaN
# ERR2314373                                                NaN
#
#            sugar_sweetened_drink_frequency        sugary_sweets_frequency  \
# sample-id
# ERR2032461    Rarely (less than once/week)  Occasionally (1-2 times/week)
# ERR1315794                    Not provided  Occasionally (1-2 times/week)
# ERR1389625                           Never     Regularly (3-5 times/week)
# ERR1389626                           Never   Rarely (less than once/week)
# ERR2313941    Rarely (less than once/week)   Rarely (less than once/week)
# ...                                    ...                            ...
# ERR2314356    Rarely (less than once/week)                          Daily
# ERR2314357                           Never     Regularly (3-5 times/week)
# ERR2314358                           Never     Regularly (3-5 times/week)
# ERR2314359                           Never                          Never
# ERR2314373                           Never   Rarely (less than once/week)
#
#                       vegetable_frequency vitamin_b_supplement_frequency  \
# sample-id
# ERR2032461  Occasionally (1-2 times/week)                          Never
# ERR1315794                          Daily                          Never
# ERR1389625                          Daily                          Never
# ERR1389626                          Daily                          Never
# ERR2313941     Regularly (3-5 times/week)     Rarely (a few times/month)
# ...                                   ...                            ...
# ERR2314356     Regularly (3-5 times/week)  Occasionally (1-2 times/week)
# ERR2314357     Regularly (3-5 times/week)                          Never
# ERR2314358                          Daily     Regularly (3-5 times/week)
# ERR2314359   Rarely (less than once/week)                          Never
# ERR2314373                          Daily     Regularly (3-5 times/week)
#
#            vitamin_d_supplement_frequency                     whole_eggs  \
# sample-id
# ERR2032461                          Never                          Never
# ERR1315794                          Daily     Regularly (3-5 times/week)
# ERR1389625                          Never     Regularly (3-5 times/week)
# ERR1389626                          Never  Occasionally (1-2 times/week)
# ERR2313941                          Never     Regularly (3-5 times/week)
# ...                                   ...                            ...
# ERR2314356  Occasionally (1-2 times/week)     Regularly (3-5 times/week)
# ERR2314357                          Never     Regularly (3-5 times/week)
# ERR2314358     Regularly (3-5 times/week)   Rarely (less than once/week)
# ERR2314359                          Never   Rarely (less than once/week)
# ERR2314373                          Never  Occasionally (1-2 times/week)
#
#                     whole_grain_frequency  \
# sample-id
# ERR2032461  Occasionally (1-2 times/week)
# ERR1315794                          Never
# ERR1389625  Occasionally (1-2 times/week)
# ERR1389626     Regularly (3-5 times/week)
# ERR2313941                   Not provided
# ...                                   ...
# ERR2314356  Occasionally (1-2 times/week)
# ERR2314357     Regularly (3-5 times/week)
# ERR2314358     Regularly (3-5 times/week)
# ERR2314359                          Never
# ERR2314373   Rarely (less than once/week)
#
#                                                     fastq_ftp
# sample-id
# ERR2032461  ftp.sra.ebi.ac.uk/vol1/fastq/ERR203/001/ERR203...
# ERR1315794  ftp.sra.ebi.ac.uk/vol1/fastq/ERR131/004/ERR131...
# ERR1389625  ftp.sra.ebi.ac.uk/vol1/fastq/ERR138/005/ERR138...
# ERR1389626  ftp.sra.ebi.ac.uk/vol1/fastq/ERR138/006/ERR138...
# ERR2313941  ftp.sra.ebi.ac.uk/vol1/fastq/ERR231/001/ERR231...
# ...                                                       ...
# ERR2314356  ftp.sra.ebi.ac.uk/vol1/fastq/ERR231/006/ERR231...
# ERR2314357  ftp.sra.ebi.ac.uk/vol1/fastq/ERR231/007/ERR231...
# ERR2314358  ftp.sra.ebi.ac.uk/vol1/fastq/ERR231/008/ERR231...
# ERR2314359  ftp.sra.ebi.ac.uk/vol1/fastq/ERR231/009/ERR231...
# ERR2314373  ftp.sra.ebi.ac.uk/vol1/fastq/ERR231/003/ERR231...
#
# [1404 rows x 45 columns]
